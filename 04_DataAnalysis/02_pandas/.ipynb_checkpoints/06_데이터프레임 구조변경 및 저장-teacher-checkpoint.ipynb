# %% [markdown]
# ## 데이터 프레임 구조 변경 및 저장
# 1. DataFrame에 새로운 컬룸을 추가하거나 원하는 자료형으로 변환하는 등의 조작.
# 2. DataFrame 객체를 csv, excel 등의 파일로 저장 및 열기

# %%
# 데이터 프레임 만들기
import pandas as pd

data = {
    '이름' : ['손흥민', '김민재', '이강인', '황의찬', '류현진', '김병현', '박찬호', '추신수'],
    '학교' : ['축구고', '축구고', '축구고', '축구고', '야구고', '야구고', '야구고', '야구고'],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90]
}

df= pd.DataFrame(data)
df
# Out:
#     이름   학교   국어   영어   수학
# 0  손흥민  축구고   90   85  100
# 1  김민재  축구고   40   35   50
# 2  이강인  축구고   80   75   70
# 3  황의찬  축구고   40   60   70
# 4  류현진  야구고   15   20   10
# 5  김병현  야구고   80  100   95
# 6  박찬호  야구고   55   65   45
# 7  추신수  야구고  100   85   90

# %%
#인덱스 변경해보기
df.index=['1번','2번','3번','4번','5번','6번','7번','8번']
df
# Out:
#      이름   학교   국어   영어   수학
# 1번  손흥민  축구고   90   85  100
# 2번  김민재  축구고   40   35   50
# 3번  이강인  축구고   80   75   70
# 4번  황의찬  축구고   40   60   70
# 5번  류현진  야구고   15   20   10
# 6번  김병현  야구고   80  100   95
# 7번  박찬호  야구고   55   65   45
# 8번  추신수  야구고  100   85   90

# %%
#인덱스 컬룸에 컬룸명을 설정하기
df.index.name='학생번호'
df
# Out:
#        이름   학교   국어   영어   수학
# 학생번호
# 1번    손흥민  축구고   90   85  100
# 2번    김민재  축구고   40   35   50
# 3번    이강인  축구고   80   75   70
# 4번    황의찬  축구고   40   60   70
# 5번    류현진  야구고   15   20   10
# 6번    김병현  야구고   80  100   95
# 7번    박찬호  야구고   55   65   45
# 8번    추신수  야구고  100   85   90

# %%
#굳이 인덱스명를 학생번호로 안해도 될것같아..그래서 원래대로 0,1,2...인덱스를 초기화
df.reset_index()
# Out:
#   학생번호   이름   학교   국어   영어   수학
# 0   1번  손흥민  축구고   90   85  100
# 1   2번  김민재  축구고   40   35   50
# 2   3번  이강인  축구고   80   75   70
# 3   4번  황의찬  축구고   40   60   70
# 4   5번  류현진  야구고   15   20   10
# 5   6번  김병현  야구고   80  100   95
# 6   7번  박찬호  야구고   55   65   45
# 7   8번  추신수  야구고  100   85   90

# %%
# reset_index()를 하면 기존 인덱스로 쓰면 컴룸들이 데이터용 컬룸으로 변경됨
# 만약. 이 학생번호가 데이터로서 필요없다면..reset_index()할때 기존 인덱스용 컴룸들을 제거하도록
df.reset_index(drop=True)
# Out:
#     이름   학교   국어   영어   수학
# 0  손흥민  축구고   90   85  100
# 1  김민재  축구고   40   35   50
# 2  이강인  축구고   80   75   70
# 3  황의찬  축구고   40   60   70
# 4  류현진  야구고   15   20   10
# 5  김병현  야구고   80  100   95
# 6  박찬호  야구고   55   65   45
# 7  추신수  야구고  100   85   90

# %%
# 위 리셋기능작업을 수행하면 원본 데이터프레임은 그대로 이고.
# 변경된 새로운 데이터프레임이 출력되었던 것임
# 그래서 현재 데이터프레임을 출력해보면.. 위 reset_index()작업이 반영되어 있지 않음
df
# Out:
#        이름   학교   국어   영어   수학
# 학생번호
# 1번    손흥민  축구고   90   85  100
# 2번    김민재  축구고   40   35   50
# 3번    이강인  축구고   80   75   70
# 4번    황의찬  축구고   40   60   70
# 5번    류현진  야구고   15   20   10
# 6번    김병현  야구고   80  100   95
# 7번    박찬호  야구고   55   65   45
# 8번    추신수  야구고  100   85   90

# %%
# reset_index()를 수행할때 원본 데이터프레임에 적용되게 하려면..
df.reset_index(drop=True, inplace=True)
df
# Out:
#     이름   학교   국어   영어   수학
# 0  손흥민  축구고   90   85  100
# 1  김민재  축구고   40   35   50
# 2  이강인  축구고   80   75   70
# 3  황의찬  축구고   40   60   70
# 4  류현진  야구고   15   20   10
# 5  김병현  야구고   80  100   95
# 6  박찬호  야구고   55   65   45
# 7  추신수  야구고  100   85   90

# %%
# 새로운 인덱스를 지정할건데..특정 컬룸의 값으로 인덱스명으로 사용하도록 변경
df.set_index('이름', inplace=True)
df
# Out:
#       학교   국어   영어   수학
# 이름
# 손흥민  축구고   90   85  100
# 김민재  축구고   40   35   50
# 이강인  축구고   80   75   70
# 황의찬  축구고   40   60   70
# 류현진  야구고   15   20   10
# 김병현  야구고   80  100   95
# 박찬호  야구고   55   65   45
# 추신수  야구고  100   85   90

# %%
#인덱스명을 기준으로 오름차순 또는 내림차순으로 정렬가능
df.sort_index() #inplace를 사용하지 않으면 원본은 그대로.
# Out:
#       학교   국어   영어   수학
# 이름
# 김민재  축구고   40   35   50
# 김병현  야구고   80  100   95
# 류현진  야구고   15   20   10
# 박찬호  야구고   55   65   45
# 손흥민  축구고   90   85  100
# 이강인  축구고   80   75   70
# 추신수  야구고  100   85   90
# 황의찬  축구고   40   60   70

# %%
df.sort_index(ascending=False)
# Out:
#       학교   국어   영어   수학
# 이름
# 황의찬  축구고   40   60   70
# 추신수  야구고  100   85   90
# 이강인  축구고   80   75   70
# 손흥민  축구고   90   85  100
# 박찬호  야구고   55   65   45
# 류현진  야구고   15   20   10
# 김병현  야구고   80  100   95
# 김민재  축구고   40   35   50

# %%
# 인덱스를 다시 지정하여 원위치...
df.reset_index(inplace=True)
df
# Out:
#     이름   학교   국어   영어   수학
# 0  손흥민  축구고   90   85  100
# 1  김민재  축구고   40   35   50
# 2  이강인  축구고   80   75   70
# 3  황의찬  축구고   40   60   70
# 4  류현진  야구고   15   20   10
# 5  김병현  야구고   80  100   95
# 6  박찬호  야구고   55   65   45
# 7  추신수  야구고  100   85   90

# %% [markdown]
# ### 새로운 컬룸 추가

# %%
# 데이터셋에 평균점수를 저장되어 있지 않음. 분석할때 마다 평균계산하지 말고..학생별 평균컬룸을 만들기
# 데이터프레임 자체에 통으로 평균계산 가능
df.mean() #error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # 데이터셋에 평균점수를 저장되어 있지 않음. 분석할때 마다 평균계산하지 말고..학생별 평균컬룸을 만들기
#       2 # 데이터프레임 자체에 통으로 평균계산 가능
# ----> 3 df.mean() #error
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)  11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11721     if isinstance(result, Series):
#   11722         result = result.__finalize__(self, method="mean")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
# ...

# %%
# 데이터프레임의 컬룸들 중에서 숫자데이터만 평균을 계산
df[['국어','영어','수학']].mean()
# Out:
# 국어    62.500
# 영어    65.625
# 수학    66.250
# dtype: float64

# %%
# 학생별 평균을 구하기 위해 평균계산을 가로방향으로 하도록..
df[['국어','영어','수학']].mean(axis=1)
# Out:
# 0    91.666667
# 1    41.666667
# 2    75.000000
# 3    56.666667
# 4    15.000000
# 5    91.666667
# 6    55.000000
# 7    91.666667
# dtype: float64

# %%
# 평균값 시리즈를 원래 데이터프레임의 '평균'칸을 새로 만들어 추가
df['평균']= df[['국어','영어','수학']].mean(axis=1)
df
# Out:
#     이름   학교   국어   영어   수학         평균
# 0  손흥민  축구고   90   85  100  91.666667
# 1  김민재  축구고   40   35   50  41.666667
# 2  이강인  축구고   80   75   70  75.000000
# 3  황의찬  축구고   40   60   70  56.666667
# 4  류현진  야구고   15   20   10  15.000000
# 5  김병현  야구고   80  100   95  91.666667
# 6  박찬호  야구고   55   65   45  55.000000
# 7  추신수  야구고  100   85   90  91.666667

# %%
#평균을 소수점 2자리까지만 표기
df['평균']= df[['국어','영어','수학']].mean(axis=1).round(2)
df
# Out:
#     이름   학교   국어   영어   수학     평균
# 0  손흥민  축구고   90   85  100  91.67
# 1  김민재  축구고   40   35   50  41.67
# 2  이강인  축구고   80   75   70  75.00
# 3  황의찬  축구고   40   60   70  56.67
# 4  류현진  야구고   15   20   10  15.00
# 5  김병현  야구고   80  100   95  91.67
# 6  박찬호  야구고   55   65   45  55.00
# 7  추신수  야구고  100   85   90  91.67

# %%
# '총점'컬룸 추가하기
df['총점']= df[['국어','영어','수학']].sum(axis='column') #axis=1
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:579, in NDFrame._get_axis_number(cls, axis)
#     578 try:
# --> 579     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     580 except KeyError:
#
# KeyError: 'column'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # '총점'컬룸 추가하기
# ----> 2 df['총점']= df[['국어','영어','수학']].sum(axis='column') #axis=1
#       3 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11697, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11688 @doc(make_doc("sum", ndim=2))
#   11689 def sum(
#   11690     self,
#    (...)  11695     **kwargs,
#   11696 ):
# ...
